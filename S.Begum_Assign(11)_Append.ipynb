# %%
#--------------------> Jayasri Class----------> Python_Append

# %%
# Task: create a program
# Q1>Create and import file
# 1. Create boys Boysfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality) ,
# 2. Create girls Girlsfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality),
# 3. Append two dataframes and print data.


# Q3>Create and import file
# 1. Create a father side fatherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)
# 2. Create a mother side montherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)
# 3. Append two dataframes and print data.

# Q4>Create and import file
# 1. Create your sister names  Sisters.xls file and import file in spyder  (atleast 5 names, columns are SisterName*Relation)
# 2. Create your brother names Brothers.xls file and import file in spyder  (atleast 5 names, columns are BrotherName*Relation)
# 3. Append two dataframes and print data.


# Q5>Create and import file
# 1. Create a Dal related  dal_items.xlsx file and import file in spyder (atleast 5 names, columns are VegFoodName*Taste)
# 2. Create a vegitable related  vegitable_items.xlsx file and import file in spyder (atleast 5 names, columns are VegFoodName*Taste)
# 3. Append two dataframes and print data.

# Q6>Create and import file
# 1. Create a soups related  soups_items.xlsx file and import file in spyder (atleast 5 names, columns are soups*Taste)
# 2. Create a fry related  fry_items.xlsx file and import file in spyder (atleast 5 names, columns are fry*Taste)
# 3. Append two dataframes and print data.

# Q7>Create and import file
# 1. Create a Chicken related chicken_items.xlsx file and import file in spyder (atleast 5 names, columns are NonVegFoodName*Taste)
# 2. Create a mutton related mutton_items.xlsx file and import file in spyder (atleast 5 names, columns are NonVegFoodName*Taste)
# 3. Append two dataframes and print data.


# Q8>Create and import file
# 1. Create a winter season  winterseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 2. Create a summer season  summerseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 3. Create a rainy season  rainyseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 4. Append all dataframes and print data.


# Q9>Create and import file
# 1. Create a red colour flowers redflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)
# 2. Create a white colour flowers whiteflowers_names.xlsx file  and import file in spyder  (atleast 3 names, columns are FlowerName*color)
# 3. Create a pink colour flowers whiteflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)
# 4. Create a yellow colour flowers whiteflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)
# 5. Append all dataframes and print data.

# %%
# Task: create a program
# Q1>Create and import file
# 1. Create boys Boysfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality) ,
# 2. Create girls Girlsfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality),
# 3. Append two dataframes and print data.

import pandas
import pandas as pd
df_b=pd.read_excel(r"C:\Users\hp\Downloads\Boysfriends_Names.xlsx")
df_b
# Out:
#    S.No. Boys Friends Name      Quality
# 0      1             Srinu  Intelligent
# 1      2             Shyam         Good
# 2      3           Rehaman  Talk active
# 3      4            Munwar     Innocent
# 4      5              Rafi         Cool
# 5      6            Prasad        Funny
# 6      7              Kali       Active
# 7      8            Rajesh  Responsible
# 8      9             Eswar      Honesty
# 9     10             Afzal     Kindness

# %%
df_g=pd.read_excel(r"C:\Users\hp\Downloads\Girlsfriends_Names.xlsx")
df_g
# Out:
#    S.No. Girls Friends Names      Quality
# 0      1              Hanima  Intelligent
# 1      2               Munni         Good
# 2      3             Parveen  Talk active
# 3      4            Nagamani     Innocent
# 4      5              Pushpa         Cool
# 5      6            Shafeeka        Funny
# 6      7             Sultana       Active
# 7      8              Devika  Responsible
# 8      9             Radhika      Honesty
# 9     10                Jaya     Kindness

# %%
new=pd.concat([df_b,df_g],axis=0)

# %%
new
# Out:
#    S.No. Boys Friends Name      Quality Girls Friends Names
# 0      1             Srinu  Intelligent                 NaN
# 1      2             Shyam         Good                 NaN
# 2      3           Rehaman  Talk active                 NaN
# 3      4            Munwar     Innocent                 NaN
# 4      5              Rafi         Cool                 NaN
# 5      6            Prasad        Funny                 NaN
# 6      7              Kali       Active                 NaN
# 7      8            Rajesh  Responsible                 NaN
# 8      9             Eswar      Honesty                 NaN
# 9     10             Afzal     Kindness                 NaN
# 0      1               NaN  Intelligent              Hanima
# 1      2               NaN         Good               Munni
# 2      3               NaN  Talk active             Parveen
# 3      4               NaN     Innocent            Nagamani
# 4      5               NaN         Cool              Pushpa
# 5      6               NaN        Funny            Shafeeka
# 6      7               NaN       Active             Sultana
# 7      8               NaN  Responsible              Devika
# 8      9               NaN      Honesty             Radhika
# 9     10               NaN     Kindness                Jaya

# %%
new1=pd.concat([df_b,df_g],axis=1)
new1
# Out:
#    S.No. Boys Friends Name      Quality  S.No. Girls Friends Names  \
# 0      1             Srinu  Intelligent      1              Hanima
# 1      2             Shyam         Good      2               Munni
# 2      3           Rehaman  Talk active      3             Parveen
# 3      4            Munwar     Innocent      4            Nagamani
# 4      5              Rafi         Cool      5              Pushpa
# 5      6            Prasad        Funny      6            Shafeeka
# 6      7              Kali       Active      7             Sultana
# 7      8            Rajesh  Responsible      8              Devika
# 8      9             Eswar      Honesty      9             Radhika
# 9     10             Afzal     Kindness     10                Jaya
#
#        Quality
# 0  Intelligent
# 1         Good
# 2  Talk active
# 3     Innocent
# 4         Cool
# 5        Funny
# 6       Active
# 7  Responsible
# 8      Honesty
# 9     Kindness

# %%
# Q3>Create and import file
# 1. Create a father side fatherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)
# 2. Create a mother side montherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)
# 3. Append two dataframes and print data.


fatherfamily_members=pd.read_excel(r"C:\Users\hp\Downloads\Ffamily_members.xlsx")
fatherfamily_members
# Out:
#    S.No. F.Family Members      Relation
# 0      1       Jani Saheb  Grand_father
# 1      2         Jainabbi  Grand_mother
# 2      3     Perveen Jaha         Aunty
# 3      4       Nawab Jani         Uncle
# 4      5   Mohammed Saheb     Chinnanna
# 5      6         Md.Samad     Chinnanna

# %%
montherfamily_members=pd.read_excel(r"C:\Users\hp\Downloads\Mfamily_members.xlsx")
montherfamily_members
# Out:
#    S.No. M.Family Members      Relation
# 0      1    Khasim Sharif  Grand_father
# 1      2     Rabiya Begum  Grand_mother
# 2      3      Naseem Jaha     peddhamma
# 3      4      Balkis Jaha     My Mother
# 4      5     Perveen Jaha         Pinni
# 5      6    Humayun Basha       Mamayya

# %%
ap=pd.concat([fatherfamily_members,montherfamily_members],axis=0)
ap
# Out:
#    S.No. F.Family Members      Relation M.Family Members
# 0      1       Jani Saheb  Grand_father              NaN
# 1      2         Jainabbi  Grand_mother              NaN
# 2      3     Perveen Jaha         Aunty              NaN
# 3      4       Nawab Jani         Uncle              NaN
# 4      5   Mohammed Saheb     Chinnanna              NaN
# 5      6         Md.Samad     Chinnanna              NaN
# 0      1              NaN  Grand_father    Khasim Sharif
# 1      2              NaN  Grand_mother     Rabiya Begum
# 2      3              NaN     peddhamma      Naseem Jaha
# 3      4              NaN     My Mother      Balkis Jaha
# 4      5              NaN         Pinni     Perveen Jaha
# 5      6              NaN       Mamayya    Humayun Basha

# %%
ap1=pd.concat([fatherfamily_members,montherfamily_members],axis=1)
ap1
# Out:
#    S.No. F.Family Members      Relation  S.No. M.Family Members      Relation
# 0      1       Jani Saheb  Grand_father      1    Khasim Sharif  Grand_father
# 1      2         Jainabbi  Grand_mother      2     Rabiya Begum  Grand_mother
# 2      3     Perveen Jaha         Aunty      3      Naseem Jaha     peddhamma
# 3      4       Nawab Jani         Uncle      4      Balkis Jaha     My Mother
# 4      5   Mohammed Saheb     Chinnanna      5     Perveen Jaha         Pinni
# 5      6         Md.Samad     Chinnanna      6    Humayun Basha       Mamayya

# %%
# Q8>Create and import file
# 1. Create a winter season  winterseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 2. Create a summer season  summerseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 3. Create a rainy season  rainyseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 4. Append all dataframes and print data.
winterseason_names=pd.read_excel(r"C:\Users\hp\Downloads\Winter_season.xlsx")
winterseason_names
# Out:
#   Month Names  Season
# 0    November  Winter
# 1    December  Winter
# 2     January  Winter

# %%
summerseason_names=pd.read_excel(r"C:\Users\hp\Downloads\Summer_Season.xlsx")
summerseason_names
# Out:
#   Month Names  Season
# 0       March  Summer
# 1       April  Summer
# 2         May  Summer

# %%
rainyseason_names=pd.read_excel(r"C:\Users\hp\Downloads\Rainy_Season.xlsx")
rainyseason_names
# Out:
#   Month Names Season
# 0        July  Rainy
# 1      August  Rainy
# 2   September  Rainy

# %%
app=pd.concat([winterseason_names,summerseason_names,rainyseason_names],axis=0)
app
# Out:
#   Month Names  Season
# 0    November  Winter
# 1    December  Winter
# 2     January  Winter
# 0       March  Summer
# 1       April  Summer
# 2         May  Summer
# 0        July   Rainy
# 1      August   Rainy
# 2   September   Rainy

# %%
app1=pd.concat([winterseason_names,summerseason_names,rainyseason_names],axis=1)
app1
# Out:
#   Month Names  Season Month Names  Season Month Names Season
# 0    November  Winter       March  Summer        July  Rainy
# 1    December  Winter       April  Summer      August  Rainy
# 2     January  Winter         May  Summer   September  Rainy

# %%
#--------------> Python_Append --------------> Assignment(11 _Practice

# %%
# Task: create a program
# Q1>Create and import file
# 1. Create boys Boysfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality) ,
# 2. Create girls Girlsfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality),
# 3. Append two dataframes and print data.

# %%
# 1. Create boys Boysfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality) 

import pandas as pd
df_Bf=pd.read_excel(r"C:\Users\hp\Downloads\Boysfriends_Names.xlsx")
df_Bf
# Out:
#    S.No. Boys Friends Name      Quality
# 0      1             Srinu  Intelligent
# 1      2             Shyam         Good
# 2      3           Rehaman  Talk active
# 3      4            Munwar     Innocent
# 4      5              Rafi         Cool
# 5      6            Prasad        Funny
# 6      7              Kali       Active
# 7      8            Rajesh  Responsible
# 8      9             Eswar      Honesty
# 9     10             Afzal     Kindness

# %%
# 2. Create girls Girlsfriend_names.xls file and import file in spyder (atleast 10 names, columns are FriendName,Quality)

import pandas as pd
df_Gf=pd.read_excel(r"C:\Users\hp\Downloads\Girlsfriends_Names.xlsx")
df_Gf
# Out:
#    S.No. Girls Friends Names      Quality
# 0      1              Hanima  Intelligent
# 1      2               Munni         Good
# 2      3             Parveen  Talk active
# 3      4            Nagamani     Innocent
# 4      5              Pushpa         Cool
# 5      6            Shafeeka        Funny
# 6      7             Sultana       Active
# 7      8              Devika  Responsible
# 8      9             Radhika      Honesty
# 9     10                Jaya     Kindness

# %%
#----------------> Append ------> (Two Tables)

# %%
Syntax:
    
df=pd.concat([Table1,Table2],axis=0)
df

# %%
axis=0 ----> Data to Display ["One by One"]

# %%
# 3. Append two dataframes and print data.

Ap=pd.concat([df_Bf,df_Gf],axis=0)
Ap
# Out:
#    S.No. Boys Friends Name      Quality Girls Friends Names
# 0      1             Srinu  Intelligent                 NaN
# 1      2             Shyam         Good                 NaN
# 2      3           Rehaman  Talk active                 NaN
# 3      4            Munwar     Innocent                 NaN
# 4      5              Rafi         Cool                 NaN
# 5      6            Prasad        Funny                 NaN
# 6      7              Kali       Active                 NaN
# 7      8            Rajesh  Responsible                 NaN
# 8      9             Eswar      Honesty                 NaN
# 9     10             Afzal     Kindness                 NaN
# 0      1               NaN  Intelligent              Hanima
# 1      2               NaN         Good               Munni
# 2      3               NaN  Talk active             Parveen
# 3      4               NaN     Innocent            Nagamani
# 4      5               NaN         Cool              Pushpa
# 5      6               NaN        Funny            Shafeeka
# 6      7               NaN       Active             Sultana
# 7      8               NaN  Responsible              Devika
# 8      9               NaN      Honesty             Radhika
# 9     10               NaN     Kindness                Jaya

# %%
Syntax:
    
df=pd.concat([Table1,Table2],axis=1)

# %%
axis=1 ----> Data to Display ["Side by Side"]

# %%
Ap1=pd.concat([df_Bf,df_Gf],axis=1)
Ap1
# Out:
#    S.No. Boys Friends Name      Quality  S.No. Girls Friends Names  \
# 0      1             Srinu  Intelligent      1              Hanima
# 1      2             Shyam         Good      2               Munni
# 2      3           Rehaman  Talk active      3             Parveen
# 3      4            Munwar     Innocent      4            Nagamani
# 4      5              Rafi         Cool      5              Pushpa
# 5      6            Prasad        Funny      6            Shafeeka
# 6      7              Kali       Active      7             Sultana
# 7      8            Rajesh  Responsible      8              Devika
# 8      9             Eswar      Honesty      9             Radhika
# 9     10             Afzal     Kindness     10                Jaya
#
#        Quality
# 0  Intelligent
# 1         Good
# 2  Talk active
# 3     Innocent
# 4         Cool
# 5        Funny
# 6       Active
# 7  Responsible
# 8      Honesty
# 9     Kindness

# %%
# Q3>Create and import file
# 1. Create a father side fatherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)
# 2. Create a mother side montherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)
# 3. Append two dataframes and print data.

# %%
# 1. Create a father side fatherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)

df_Ffm=pd.read_excel(r"C:\Users\hp\Downloads\Ffamily_members.xlsx")
df_Ffm
# Out:
#    S.No. F.Family Members      Relation
# 0      1       Jani Saheb  Grand_father
# 1      2         Jainabbi  Grand_mother
# 2      3     Perveen Jaha         Aunty
# 3      4       Nawab Jani         Uncle
# 4      5   Mohammed Saheb     Chinnanna
# 5      6         Md.Samad     Chinnanna

# %%
# 2. Create a mother side montherfamily_members.xls file and import file in spyder  (atleast 5 names, columns are FamilyMemberName*Relation)

df_Mfm=pd.read_excel(r"C:\Users\hp\Downloads\Mfamily_members.xlsx")
df_Mfm
# Out:
#    S.No. M.Family Members      Relation
# 0      1    Khasim Sharif  Grand_father
# 1      2     Rabiya Begum  Grand_mother
# 2      3      Naseem Jaha     peddhamma
# 3      4      Balkis Jaha     My Mother
# 4      5     Perveen Jaha         Pinni
# 5      6    Humayun Basha       Mamayya

# %%
# 3. Append two dataframes and print data.

Ap=pd.concat([df_Ffm,df_Mfm],axis=0)
Ap
# Out:
#    S.No. F.Family Members      Relation M.Family Members
# 0      1       Jani Saheb  Grand_father              NaN
# 1      2         Jainabbi  Grand_mother              NaN
# 2      3     Perveen Jaha         Aunty              NaN
# 3      4       Nawab Jani         Uncle              NaN
# 4      5   Mohammed Saheb     Chinnanna              NaN
# 5      6         Md.Samad     Chinnanna              NaN
# 0      1              NaN  Grand_father    Khasim Sharif
# 1      2              NaN  Grand_mother     Rabiya Begum
# 2      3              NaN     peddhamma      Naseem Jaha
# 3      4              NaN     My Mother      Balkis Jaha
# 4      5              NaN         Pinni     Perveen Jaha
# 5      6              NaN       Mamayya    Humayun Basha

# %%
Ap1=pd.concat([df_Ffm,df_Mfm],axis=1)
Ap1
# Out:
#    S.No. F.Family Members      Relation  S.No. M.Family Members      Relation
# 0      1       Jani Saheb  Grand_father      1    Khasim Sharif  Grand_father
# 1      2         Jainabbi  Grand_mother      2     Rabiya Begum  Grand_mother
# 2      3     Perveen Jaha         Aunty      3      Naseem Jaha     peddhamma
# 3      4       Nawab Jani         Uncle      4      Balkis Jaha     My Mother
# 4      5   Mohammed Saheb     Chinnanna      5     Perveen Jaha         Pinni
# 5      6         Md.Samad     Chinnanna      6    Humayun Basha       Mamayya

# %%
# Q4>Create and import file
# 1. Create your sister names  Sisters.xls file and import file in spyder  (atleast 5 names, columns are SisterName*Relation)
# 2. Create your brother names Brothers.xls file and import file in spyder  (atleast 5 names, columns are BrotherName*Relation)
# 3. Append two dataframes and print data.

# %%
# 1. Create your sister names  Sisters.xls file and import file in spyder  (atleast 5 names, columns are SisterName*Relation)

df_Sis=pd.read_excel(r"C:\Users\hp\Downloads\Sisters_Names.xlsx")
df_Sis
# Out:
#    S.No. Sis_Names        Relation
# 0      1     Abida    Elder_Sister
# 1      2  Shahanaz    Elder_Sister
# 2      3   Husnara    Elder_Sister
# 3      4  Shakeela  Younger_Sister
# 4      5   Sultana    Elder_Sister

# %%
# 2. Create your brother names Brothers.xls file and import file in spyder  (atleast 5 names, columns are BrotherName*Relation)

df_Bro=pd.read_excel(r"C:\Users\hp\Downloads\Brothers_Names.xlsx")
df_Bro
# Out:
#    S.No.   Bro_Names         Relation
# 0      1      Shammi    Elder_Brother
# 1      2      Shamun    Elder_Brother
# 2      3     Shakeel  Younger_Brother
# 3      4     Khaleel    Elder_Brother
# 4      5  Afzal Shaw    Elder_Brother

# %%
# 3. Append two dataframes and print data.

Ap=pd.concat([df_Sis,df_Bro],axis=0)
Ap
# Out:
#    S.No. Sis_Names         Relation   Bro_Names
# 0      1     Abida     Elder_Sister         NaN
# 1      2  Shahanaz     Elder_Sister         NaN
# 2      3   Husnara     Elder_Sister         NaN
# 3      4  Shakeela   Younger_Sister         NaN
# 4      5   Sultana     Elder_Sister         NaN
# 0      1       NaN    Elder_Brother      Shammi
# 1      2       NaN    Elder_Brother      Shamun
# 2      3       NaN  Younger_Brother     Shakeel
# 3      4       NaN    Elder_Brother     Khaleel
# 4      5       NaN    Elder_Brother  Afzal Shaw

# %%
Ap2=pd.concat([df_Sis,df_Bro],axis=1)
Ap2
# Out:
#    S.No. Sis_Names        Relation  S.No.   Bro_Names         Relation
# 0      1     Abida    Elder_Sister      1      Shammi    Elder_Brother
# 1      2  Shahanaz    Elder_Sister      2      Shamun    Elder_Brother
# 2      3   Husnara    Elder_Sister      3     Shakeel  Younger_Brother
# 3      4  Shakeela  Younger_Sister      4     Khaleel    Elder_Brother
# 4      5   Sultana    Elder_Sister      5  Afzal Shaw    Elder_Brother

# %%
# Q5>Create and import file
# 1. Create a Dal related  dal_items.xlsx file and import file in spyder (atleast 5 names, columns are VegFoodName*Taste)
# 2. Create a vegitable related  vegitable_items.xlsx file and import file in spyder (atleast 5 names, columns are VegFoodName*Taste)
# 3. Append two dataframes and print data.

# %%
# 1. Create a Dal related  dal_items.xlsx file and import file in spyder (atleast 5 names, columns are VegFoodName*Taste)

df_Dal=pd.read_excel(r"C:\Users\hp\Downloads\dal_items.xlsx")
df_Dal
# Out:
#    S.No.     Dal_Names      Taste
# 0      1    Tomato dal  Excellent
# 1      2       Sambaar     Supper
# 2      3   Brinjal dal  Excellent
# 3      4  Ridge  gourd       Good
# 4      5   Cabbage dal    Average

# %%
# 2. Create a vegitable related  vegitable_items.xlsx file and import file in spyder (atleast 5 names, columns are VegFoodName*Taste)

df_Veg=pd.read_excel(r"C:\Users\hp\Downloads\VegFood_ Names.xlsx")
df_Veg
# Out:
#    S.No.          Veg_Names      Taste
# 0      1         Potato Fry      Spicy
# 1      2   Snake gard Curry       Good
# 2      3      Brinjal Curry  Excellent
# 3      4  Ladies finger Fry      Yammy
# 4      5       Tomato Curry     Supper

# %%
# 3. Append two dataframes and print data.

Ap=pd.concat([df_Dal,df_Veg],axis=0)
Ap
# Out:
#    S.No.     Dal_Names      Taste          Veg_Names
# 0      1    Tomato dal  Excellent                NaN
# 1      2       Sambaar     Supper                NaN
# 2      3   Brinjal dal  Excellent                NaN
# 3      4  Ridge  gourd       Good                NaN
# 4      5   Cabbage dal    Average                NaN
# 0      1           NaN      Spicy         Potato Fry
# 1      2           NaN       Good   Snake gard Curry
# 2      3           NaN  Excellent      Brinjal Curry
# 3      4           NaN      Yammy  Ladies finger Fry
# 4      5           NaN     Supper       Tomato Curry

# %%
Ap3=pd.concat([df_Dal,df_Veg],axis=1)
Ap3
# Out:
#    S.No.     Dal_Names      Taste  S.No.          Veg_Names      Taste
# 0      1    Tomato dal  Excellent      1         Potato Fry      Spicy
# 1      2       Sambaar     Supper      2   Snake gard Curry       Good
# 2      3   Brinjal dal  Excellent      3      Brinjal Curry  Excellent
# 3      4  Ridge  gourd       Good      4  Ladies finger Fry      Yammy
# 4      5   Cabbage dal    Average      5       Tomato Curry     Supper

# %%
# Q6>Create and import file
# 1. Create a soups related  soups_items.xlsx file and import file in spyder (atleast 5 names, columns are soups*Taste)
# 2. Create a fry related  fry_items.xlsx file and import file in spyder (atleast 5 names, columns are fry*Taste)
# 3. Append two dataframes and print data.

# %%
# 1. Create a soups related  soups_items.xlsx file and import file in spyder (atleast 5 names, columns are soups*Taste)

df_Soups=pd.read_excel(r"C:\Users\hp\Downloads\Soup_items.xlsx")
df_Soups
# Out:
#    S.No.            Soups   Taste
# 0      1      Tomato Soup   Yammy
# 1      2     Chicken Soup  Supper
# 2      3      Matton Soup   Spicy
# 3      4      Noodle Soup     Hot
# 4      5  Sweet Corn Soup   Spicy

# %%
# 2. Create a fry related  fry_items.xlsx file and import file in spyder (atleast 5 names, columns are fry*Taste)

df_fry=pd.read_excel(r"C:\Users\hp\Downloads\Fry_items.xlsx")
df_fry
# Out:
#    S.No.         Fry _items   Taste
# 0      1         Potato Fry  Supper
# 1      2         Matton Fry   Spicy
# 2      3        Chicken Fry     Hot
# 3      4  Ladies Finger Fry   Yammy
# 4      5           Fish Fry   Spicy

# %%
# 3. Append two dataframes and print data.

Ap=pd.concat([df_Soups,df_fry],axis=0)
Ap
# Out:
#    S.No.            Soups   Taste         Fry _items
# 0      1      Tomato Soup   Yammy                NaN
# 1      2     Chicken Soup  Supper                NaN
# 2      3      Matton Soup   Spicy                NaN
# 3      4      Noodle Soup     Hot                NaN
# 4      5  Sweet Corn Soup   Spicy                NaN
# 0      1              NaN  Supper         Potato Fry
# 1      2              NaN   Spicy         Matton Fry
# 2      3              NaN     Hot        Chicken Fry
# 3      4              NaN   Yammy  Ladies Finger Fry
# 4      5              NaN   Spicy           Fish Fry

# %%
Ap1=pd.concat([df_Soups,df_fry],axis=1)
Ap1
# Out:
#    S.No.            Soups   Taste  S.No.         Fry _items   Taste
# 0      1      Tomato Soup   Yammy      1         Potato Fry  Supper
# 1      2     Chicken Soup  Supper      2         Matton Fry   Spicy
# 2      3      Matton Soup   Spicy      3        Chicken Fry     Hot
# 3      4      Noodle Soup     Hot      4  Ladies Finger Fry   Yammy
# 4      5  Sweet Corn Soup   Spicy      5           Fish Fry   Spicy

# %%
# Q7>Create and import file
# 1. Create a Chicken related chicken_items.xlsx file and import file in spyder (atleast 5 names, columns are NonVegFoodName*Taste)
# 2. Create a mutton related mutton_items.xlsx file and import file in spyder (atleast 5 names, columns are NonVegFoodName*Taste)
# 3. Append two dataframes and print data.

# %%
# 1. Create a Chicken related chicken_items.xlsx file and import file in spyder (atleast 5 names, columns are NonVegFoodName*Taste)

df_Chicken=pd.read_excel(r"C:\Users\hp\Downloads\Chicken_items.xlsx")
df_Chicken
# Out:
#    S.No. Chicken Food Names      Taste
# 0      1    Chicken Biryani  Excellent
# 1      2     Chicken Khurma     Supper
# 2      3       Chicken  Fry      Spicy
# 3      4     Chicken Chilly       Good
# 4      5       Chicken Soup    Average

# %%
# 2. Create a mutton related mutton_items.xlsx file and import file in spyder (atleast 5 names, columns are NonVegFoodName*Taste)

df_Matton=pd.read_excel(r"C:\Users\hp\Downloads\Matton_items.xlsx")
df_Matton
# Out:
#    S.No.    Matton Food Names      Taste
# 0      1       Matton Biryani  Excellent
# 1      2        Matton Khurma     Supper
# 2      3           Matton Fry     Crispy
# 3      4  Matton Masala Curry      Spicy
# 4      5          Matton Paya       Good

# %%
# 3. Append two dataframes and print data.

Ap=pd.concat([df_Chicken,df_Matton],axis=0)
Ap
# Out:
#    S.No. Chicken Food Names      Taste    Matton Food Names
# 0      1    Chicken Biryani  Excellent                  NaN
# 1      2     Chicken Khurma     Supper                  NaN
# 2      3       Chicken  Fry      Spicy                  NaN
# 3      4     Chicken Chilly       Good                  NaN
# 4      5       Chicken Soup    Average                  NaN
# 0      1                NaN  Excellent       Matton Biryani
# 1      2                NaN     Supper        Matton Khurma
# 2      3                NaN     Crispy           Matton Fry
# 3      4                NaN      Spicy  Matton Masala Curry
# 4      5                NaN       Good          Matton Paya

# %%
Ap3=pd.concat([df_Chicken,df_Matton],axis=1)
Ap3
# Out:
#    S.No. Chicken Food Names      Taste  S.No.    Matton Food Names      Taste
# 0      1    Chicken Biryani  Excellent      1       Matton Biryani  Excellent
# 1      2     Chicken Khurma     Supper      2        Matton Khurma     Supper
# 2      3       Chicken  Fry      Spicy      3           Matton Fry     Crispy
# 3      4     Chicken Chilly       Good      4  Matton Masala Curry      Spicy
# 4      5       Chicken Soup    Average      5          Matton Paya       Good

# %%
# Q8>Create and import file
# 1. Create a winter season  winterseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 2. Create a summer season  summerseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 3. Create a rainy season  rainyseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)
# 4. Append all dataframes and print data.

# %%
# 1. Create a winter season  winterseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)

df_Winter=pd.read_excel(r"C:\Users\hp\Downloads\Winter_season.xlsx")
df_Winter
# Out:
#    S.No. Month Names  Season
# 0      1    November  Winter
# 1      2    December  Winter
# 2      3     January  Winter

# %%
# 2. Create a summer season  summerseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)

df_Summer=pd.read_excel(r"C:\Users\hp\Downloads\Summer_Season.xlsx")
df_Summer
# Out:
#    S.No. Month Names  Season
# 0      1       March  Summer
# 1      2       April  Summer
# 2      3         May  Summer

# %%
# 3. Create a rainy season  rainyseason_names.xlsx file and import file in spyder  (atleast 2 names, columns are MonthName*Season)

df_Rainy=pd.read_excel(r"C:\Users\hp\Downloads\Rainy_Season.xlsx")
df_Rainy
# Out:
#    S.No. Month Names Season
# 0      1        July  Rainy
# 1      2      August  Rainy
# 2      3   September  Rainy

# %%
#----------------------> "Three Table's"----------> Append (One by One)

# %%
# 4. Append all dataframes and print data.

Ap=pd.concat([df_Winter,df_Summer,df_Rainy],axis=0)
Ap
# Out:
#    S.No. Month Names  Season
# 0      1    November  Winter
# 1      2    December  Winter
# 2      3     January  Winter
# 0      1       March  Summer
# 1      2       April  Summer
# 2      3         May  Summer
# 0      1        July   Rainy
# 1      2      August   Rainy
# 2      3   September   Rainy

# %%
""#----------> "ThreeTable's" Append (Side by Side)

# %%
Ap4=pd.concat([df_Winter,df_Summer,df_Rainy],axis=1)
Ap4
# Out:
#    S.No. Month Names  Season  S.No. Month Names  Season  S.No. Month Names  \
# 0      1    November  Winter      1       March  Summer      1        July
# 1      2    December  Winter      2       April  Summer      2      August
# 2      3     January  Winter      3         May  Summer      3   September
#
#   Season
# 0  Rainy
# 1  Rainy
# 2  Rainy

# %%
# Q9>Create and import file
# 1. Create a red colour flowers redflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)
# 2. Create a white colour flowers whiteflowers_names.xlsx file  and import file in spyder  (atleast 3 names, columns are FlowerName*color)
# 3. Create a pink colour flowers whiteflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)
# 4. Create a yellow colour flowers whiteflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)
# 5. Append all dataframes and print data.

# %%
# 1. Create a red colour flowers redflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)

import pandas as pd
df_Red=pd.read_excel(r"C:\Users\hp\Downloads\Redflowers_Names.xlsx")
df_Red
# Out:
#    S.No. Flower Names Colour
# 0      1         Rose    Red
# 1      2        Poppy    Red
# 2      3     Marigold    Red
# 3      4      Hibicus    Red

# %%
# 2. Create a white colour flowers whiteflowers_names.xlsx file  and import file in spyder  (atleast 3 names, columns are FlowerName*color)

df_White=pd.read_excel(r"C:\Users\hp\Downloads\Whiteflowers_Names.xlsx")
df_White
# Out:
#    S.No. Flower  Names Colour
# 0      1          Lily  White
# 1      2         Daisy  White
# 2      3         Roses  White
# 3      4         Peony  White

# %%
# 3. Create a pink colour flowers whiteflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)

df_Pink=pd.read_excel(r"C:\Users\hp\Downloads\Pinkflowers_Names.xlsx")
df_Pink
# Out:
#    S.No. Flower Names Colour
# 0      1         Rose   Pink
# 1      2       Tulips   Pink
# 2      3        Lotus   Pink
# 3      4  Spider Lily   Pink

# %%
# 4. Create a yellow colour flowers whiteflowers_names.xlsx file and import file in spyder   (atleast 3 names, columns are FlowerName*color)

df_Yellow=pd.read_excel(r"C:\Users\hp\Downloads\Yellowflowers_Names.xlsx")
df_Yellow
# Out:
#    S.No.    Flower Names  Colour
# 0      1        Hibiscus  Yellow
# 1      2       Bar Berry  Yellow
# 2      3    Butter Daisy  Yellow
# 3      4  Winter Jasmine  Yellow

# %%
# 5. Append all dataframes and print data.

# %%
Ap5=pd.concat([df_Red,df_Pink,df_Yellow],axis=1)
Ap5
# Out:
#    S.No. Flower Names Colour  S.No. Flower Names Colour  S.No.  \
# 0      1         Rose    Red      1         Rose   Pink      1
# 1      2        Poppy    Red      2       Tulips   Pink      2
# 2      3     Marigold    Red      3        Lotus   Pink      3
# 3      4      Hibicus    Red      4  Spider Lily   Pink      4
#
#      Flower Names  Colour
# 0        Hibiscus  Yellow
# 1       Bar Berry  Yellow
# 2    Butter Daisy  Yellow
# 3  Winter Jasmine  Yellow
